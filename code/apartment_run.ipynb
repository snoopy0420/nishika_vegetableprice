# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# !nvidia-smi

# %%
# !pip install shap
# !pip install japanize_matplotlib

# %%
# %cd drive/MyDrive/ml_pipeline/code/

# %%
import os
os.environ['HDF5_DISABLE_VERSION_CHECK']='1'

# %%
# %%time
# !python create_features.py
# Out:
# train shape:  (637351, 22)
# test shape:  (19466, 22)
# Wall time: 53 s
# ['市区町村コード', '都道府県名', '地区名', '最寄駅：名称', '最寄駅：距離（分）', '間取り', '面積（㎡）', '建築年', '建物の構造', '用途', '今後の利用目的', '都市計画', '建ぺい率（％）', '容積率（％）', '取引時点', '改装', '取引の事情等', '面積_2000', '取引年']
# C:\Users\pyworks\competitions\nishika_apartment\code\util.py:16: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yml = yaml.load(file)

# %%
# %%time 
# !python select_features.py

# %%
# %%time
# !python run.py
# Out:
#         市区町村コード 都道府県名     地区名      最寄駅：名称  ...   改装 取引の事情等  面積_2000   取引年Wall time: 37min 24s
#
# 0          1108   北海道    大谷地東         大谷地  ...  未改装    NaN    False  2010
# 3          1108   北海道  厚別中央２条  ひばりが丘(北海道)  ...  未改装    NaN    False  2016
# 4          1108   北海道   厚別東４条       新さっぽろ  ...  未改装    NaN    False  2013
# 5          1101   北海道   南１１条西        中島公園  ...  未改装    NaN    False  2017
# 6          1101   北海道   南１３条西         幌平橋  ...  未改装    NaN    False  2010
# ...         ...   ...     ...         ...  ...  ...    ...      ...   ...
# 637343    47211   沖縄県      住吉         NaN  ...  未改装    NaN    False  2012
# 637345    47208   沖縄県      宮城         NaN  ...  未改装    NaN    False  2020
# 637346    47211   沖縄県      美里         NaN  ...  未改装    NaN    False  2018
# 637349    47201   沖縄県      松尾     県庁前(沖縄)  ...  未改装    NaN    False  2019
# 637350    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2017
#
# [509880 rows x 19 columns]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.450824 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11726
# [LightGBM] [Info] Number of data points in the train set: 509880, number of used features: 18
# [LightGBM] [Info] Start training from score 7.217515
#         市区町村コード 都道府県名    地区名 最寄駅：名称  ...   改装 取引の事情等  面積_2000   取引年
# 0          1108   北海道   大谷地東    大谷地  ...  未改装    NaN    False  2010
# 1          1101   北海道   南９条西   中島公園  ...  未改装    NaN    False  2018
# 2          1101   北海道   北３条西  西１１丁目  ...  未改装    NaN    False  2010
# 4          1108   北海道  厚別東４条  新さっぽろ  ...  未改装    NaN    False  2013
# 5          1101   北海道  南１１条西   中島公園  ...  未改装    NaN    False  2017
# ...         ...   ...    ...    ...  ...  ...    ...      ...   ...
# 637345    47208   沖縄県     宮城    NaN  ...  未改装    NaN    False  2020
# 637346    47211   沖縄県     美里    NaN  ...  未改装    NaN    False  2018
# 637347    47211   沖縄県     泡瀬    NaN  ...  未改装    NaN    False  2015
# 637348    47208   沖縄県     城間    NaN  ...  未改装    NaN    False  2010
# 637350    47208   沖縄県     城間    NaN  ...  未改装    NaN    False  2017
#
# [509881 rows x 19 columns]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.311629 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11681
# [LightGBM] [Info] Number of data points in the train set: 509881, number of used features: 18
# [LightGBM] [Info] Start training from score 7.218029
#         市区町村コード 都道府県名     地区名      最寄駅：名称  ...   改装 取引の事情等  面積_2000   取引年
# 1          1101   北海道    南９条西        中島公園  ...  未改装    NaN    False  2018
# 2          1101   北海道    北３条西       西１１丁目  ...  未改装    NaN    False  2010
# 3          1108   北海道  厚別中央２条  ひばりが丘(北海道)  ...  未改装    NaN    False  2016
# 4          1108   北海道   厚別東４条       新さっぽろ  ...  未改装    NaN    False  2013
# 2021-02-21 15:18:51.971563: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_101.dll'; dlerror: cudart64_101.dll not found
# 2021-02-21 15:18:51.972285: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Warning! ***HDF5 library version mismatched error***
# The HDF5 header files used to compile this application do not match
# the version used by the HDF5 library to which this application is linked.
# Data corruption or segmentation faults may occur if the application continues.
# This can happen when an application was compiled by one version of HDF5 but
# linked with a different version of static or shared HDF5 library.
# You should recompile the application or check your shared library related
# settings such as 'LD_LIBRARY_PATH'.
# 'HDF5_DISABLE_VERSION_CHECK' environment variable is set to 1, application will
# continue at your own risk.
# Headers are 1.10.4, library is 1.10.5
#         SUMMARY OF THE HDF5 CONFIGURATION
#         =================================
#
# General Information:
# -------------------
#                    HDF5 Version: 1.10.5
#                   Configured on: 2019-03-04
#                   Configured by: Visual Studio 15 2017 Win64
#                     Host system: Windows-10.0.17763
#               Uname information: Windows
#                        Byte sex: little-endian
#              Installation point: C:/Program Files/HDF5
#
# Compiling Options:
# ------------------
#                      Build Mode:
#               Debugging Symbols:
#                         Asserts:
#                       Profiling:
#              Optimization Level:
#
# Linking Options:
# ----------------
#                       Libraries:
#   Statically Linked Executables: OFF
#                         LDFLAGS: /machine:x64
#                      H5_LDFLAGS:
#                      AM_LDFLAGS:
#                 Extra libraries:
#                        Archiver:
#                          Ranlib:
#
# Languages:
# ----------
#                               C: yes
#                      C Compiler: C:/Program Files (x86)/Microsoft Visual Studio/2017/Community/VC/Tools/MSVC/14.16.27023/bin/Hostx86/x64/cl.exe 19.16.27027.1
#                        CPPFLAGS:
#                     H5_CPPFLAGS:
# 5          1101   北海道   南１１条西        中島公園  ...  未改装    NaN    False  2017
# ...         ...   ...     ...         ...  ...  ...    ...      ...   ...
# 637344    47201   沖縄県      識名         NaN  ...  未改装    NaN    False  2008
# 637345    47208   沖縄県      宮城         NaN  ...  未改装    NaN    False  2020
# 637347    47211   沖縄県      泡瀬         NaN  ...  未改装    NaN    False  2015
# 637348    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2010
# 637349    47201   沖縄県      松尾     県庁前(沖縄)  ...  未改装    NaN    False  2019
#
# [509881 rows x 19 columns]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.087321 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11660
# [LightGBM] [Info] Number of data points in the train set: 509881, number of used features: 18
# [LightGBM] [Info] Start training from score 7.217107
#         市区町村コード 都道府県名     地区名      最寄駅：名称  ...   改装 取引の事情等  面積_2000   取引年
# 0          1108   北海道    大谷地東         大谷地  ...  未改装    NaN    False  2010
# 1          1101   北海道    南９条西        中島公園  ...  未改装    NaN    False  2018
# 2          1101   北海道    北３条西       西１１丁目  ...  未改装    NaN    False  2010
# 3          1108   北海道  厚別中央２条  ひばりが丘(北海道)  ...  未改装    NaN    False  2016
# 6          1101   北海道   南１３条西         幌平橋  ...  未改装    NaN    False  2010
# ...         ...   ...     ...         ...  ...  ...    ...      ...   ...
# 637346    47211   沖縄県      美里         NaN  ...  未改装    NaN    False  2018
# 637347    47211   沖縄県      泡瀬         NaN  ...  未改装    NaN    False  2015
# 637348    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2010
# 637349    47201   沖縄県      松尾     県庁前(沖縄)  ...  未改装    NaN    False  2019
# 637350    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2017
#
# [509881 rows x 19 columns]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.527040 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11658
# [LightGBM] [Info] Number of data points in the train set: 509881, number of used features: 18
# [LightGBM] [Info] Start training from score 7.216959
#         市区町村コード 都道府県名     地区名      最寄駅：名称  ...   改装 取引の事情等  面積_2000   取引年
# 0          1108   北海道    大谷地東         大谷地  ...  未改装    NaN    False  2010
# 1          1101   北海道    南９条西        中島公園  ...  未改装    NaN    False  2018
# 2          1101   北海道    北３条西       西１１丁目  ...  未改装    NaN    False  2010
# 3          1108   北海道  厚別中央２条  ひばりが丘(北海道)  ...  未改装    NaN    False  2016
# 4          1108   北海道   厚別東４条       新さっぽろ  ...  未改装    NaN    False  2013
# ...         ...   ...     ...         ...  ...  ...    ...      ...   ...
# 637346    47211   沖縄県      美里         NaN  ...  未改装    NaN    False  2018
# 637347    47211   沖縄県      泡瀬         NaN  ...  未改装    NaN    False  2015
# 637348    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2010
# 637349    47201   沖縄県      松尾     県庁前(沖縄)  ...  未改装    NaN    False  2019
# 637350    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2017
#
# [509881 rows x 19 columns]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.059000 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11650
# [LightGBM] [Info] Number of data points in the train set: 509881, number of used features: 18
# [LightGBM] [Info] Start training from score 7.217509
#                     AM_CPPFLAGS:
#                          CFLAGS:  /DWIN32 /D_WINDOWS /W3
#                       H5_CFLAGS:
#                       AM_CFLAGS:
#                Shared C Library: YES
#                Static C Library: YES
#
#                         Fortran: OFF
#                Fortran Compiler:
#                   Fortran Flags:
#                H5 Fortran Flags:
#                AM Fortran Flags:
#          Shared Fortran Library: YES
#          Static Fortran Library: YES
#
#                             C++: ON
#                    C++ Compiler: C:/Program Files (x86)/Microsoft Visual Studio/2017/Community/VC/Tools/MSVC/14.16.27023/bin/Hostx86/x64/cl.exe 19.16.27027.1
#                       C++ Flags: /DWIN32 /D_WINDOWS /W3 /GR /EHsc
#                    H5 C++ Flags:
#                    AM C++ Flags:
#              Shared C++ Library: YES
#              Static C++ Library: YES
#
#                             JAVA: OFF
#                    JAVA Compiler:
#
# Features:
# ---------
#                    Parallel HDF5: OFF
# Parallel Filtered Dataset Writes:
#               Large Parallel I/O:
#               High-level library: ON
#                     Threadsafety: OFF
#              Default API mapping: v110
#   With deprecated public symbols: ON
#           I/O filters (external):  DEFLATE DECODE ENCODE
#                              MPE:
#                       Direct VFD:
#                          dmalloc:
#   Packages w/ extra debug output:
#                      API Tracing: OFF
#             Using memory checker: OFF
#  Memory allocation sanity checks: OFF
#           Function Stack Tracing: OFF
#        Strict File Format Checks: OFF
#     Optimization Instrumentation:
# C:\Users\ishizuka\Anaconda3\lib\site-packages\h5py\__init__.py:40: UserWarning: h5py is running against HDF5 1.10.5 when it was built against 1.10.4, this may cause problems
#   '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# [2021-02-21 15:19:24] - lgb_KFold_02211519 - train_x shape: (637351, 19)
# [2021-02-21 15:19:24] - lgb_KFold_02211519 - train_y shape: (637351,)
# [2021-02-21 15:19:24] - lgb_KFold_02211519 - start training cv
# [2021-02-21 15:19:24] - lgb_KFold_02211519 - cv method: KFold
# [2021-02-21 15:19:24] - lgb_KFold_02211519 fold 0 - start training
# [2021-02-21 15:27:42] - lgb_KFold_02211519 fold 0 - end training - score 0.07820663346766363
# [2021-02-21 15:27:45] - lgb_KFold_02211519 fold 1 - start training
# [2021-02-21 15:35:28] - lgb_KFold_02211519 fold 1 - end training - score 0.0782579280260347
# [2021-02-21 15:35:31] - lgb_KFold_02211519 fold 2 - start training
# [2021-02-21 15:43:07] - lgb_KFold_02211519 fold 2 - end training - score 0.0775968650544751
# [2021-02-21 15:43:12] - lgb_KFold_02211519 fold 3 - start training
# [2021-02-21 15:48:46] - lgb_KFold_02211519 fold 3 - end training - score 0.07795764380851052
# [2021-02-21 15:48:49] - lgb_KFold_02211519 fold 4 - start training
# [2021-02-21 15:54:53] - lgb_KFold_02211519 fold 4 - end training - score 0.07773621807809962
# [2021-02-21 15:54:55] - lgb_KFold_02211519 - end training cv - score 0.07795105768695672
# name:lgb_KFold_02211519	score:0.07795105768695672	score0:0.07820663346766363	score1:0.0782579280260347	score2:0.0775968650544751	score3:0.07795764380851052	score4:0.07773621807809962
# mean: 0.07795105768695672, std: 0.0002573481067056965
# [2021-02-21 15:55:03] - lgb_KFold_02211519 - start prediction cv
# [2021-02-21 15:55:04] - lgb_KFold_02211519 - start prediction fold:0
# [2021-02-21 15:55:09] - lgb_KFold_02211519 - end prediction fold:0
# [2021-02-21 15:55:09] - lgb_KFold_02211519 - start prediction fold:1
# [2021-02-21 15:55:13] - lgb_KFold_02211519 - end prediction fold:1
# [2021-02-21 15:55:13] - lgb_KFold_02211519 - start prediction fold:2
# [2021-02-21 15:55:19] - lgb_KFold_02211519 - end prediction fold:2
# [2021-02-21 15:55:19] - lgb_KFold_02211519 - start prediction fold:3
# [2021-02-21 15:55:23] - lgb_KFold_02211519 - end prediction fold:3
# [2021-02-21 15:55:23] - lgb_KFold_02211519 - start prediction fold:4
# [2021-02-21 15:55:27] - lgb_KFold_02211519 - end prediction fold:4
# [2021-02-21 15:55:27] - lgb_KFold_02211519 - end prediction cv
# [2021-02-21 15:55:27] - lgb_KFold_02211519 - start create submission
# [2021-02-21 15:55:28] - lgb_KFold_02211519 - end create submission
# 2021-02-21 15:01:18.333844: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_101.dll'; dlerror: cudart64_101.dll not found
# 2021-02-21 15:01:18.381444: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Warning! ***HDF5 library version mismatched error***
# The HDF5 header files used to compile this application do not match
# the version used by the HDF5 library to which this application is linked.
# Data corruption or segmentation faults may occur if the application continues.
# This can happen when an application was compiled by one version of HDF5 but
# linked with a different version of static or shared HDF5 library.
# You should recompile the application or check your shared library related
# settings such as 'LD_LIBRARY_PATH'.
# 'HDF5_DISABLE_VERSION_CHECK' environment variable is set to 1, application will
# continue at your own risk.
# Headers are 1.10.4, library is 1.10.5
#         SUMMARY OF THE HDF5 CONFIGURATION
#         =================================
#
# General Information:
# -------------------
#                    HDF5 Version: 1.10.5
#                   Configured on: 2019-03-04
#                   Configured by: Visual Studio 15 2017 Win64
#                     Host system: Windows-10.0.17763
#               Uname information: Windows
#                        Byte sex: little-endian
#              Installation point: C:/Program Files/HDF5
#
# Compiling Options:
# ------------------
#                      Build Mode:
#               Debugging Symbols:
#                         Asserts:
#                       Profiling:
#              Optimization Level:
#
# Linking Options:
# ----------------
#                       Libraries:
#   Statically Linked Executables: OFF
#                         LDFLAGS: /machine:x64
#                      H5_LDFLAGS:
#                      AM_LDFLAGS:
#                 Extra libraries:
#                        Archiver:
#                          Ranlib:
#
# Languages:
# ----------
#                               C: yes
#                      C Compiler: C:/Program Files (x86)/Microsoft Visual Studio/2017/Community/VC/Tools/MSVC/14.16.27023/bin/Hostx86/x64/cl.exe 19.16.27027.1
#                        CPPFLAGS:
#                     H5_CPPFLAGS:
#                     AM_CPPFLAGS:
#                          CFLAGS:  /DWIN32 /D_WINDOWS /W3
#                       H5_CFLAGS:
#                       AM_CFLAGS:
#                Shared C Library: YES
#                Static C Library: YES
#
#                         Fortran: OFF
#                Fortran Compiler:
#                   Fortran Flags:
#                H5 Fortran Flags:
#                AM Fortran Flags:
#          Shared Fortran Library: YES
#          Static Fortran Library: YES
#
#                             C++: ON
#                    C++ Compiler: C:/Program Files (x86)/Microsoft Visual Studio/2017/Community/VC/Tools/MSVC/14.16.27023/bin/Hostx86/x64/cl.exe 19.16.27027.1
#                       C++ Flags: /DWIN32 /D_WINDOWS /W3 /GR /EHsc
#                    H5 C++ Flags:
#                    AM C++ Flags:
#              Shared C++ Library: YES
#              Static C++ Library: YES
#
#                             JAVA: OFF
#                    JAVA Compiler:
#
# Features:
# ---------
#                    Parallel HDF5: OFF
# Parallel Filtered Dataset Writes:
#               Large Parallel I/O:
#               High-level library: ON
#                     Threadsafety: OFF
#              Default API mapping: v110
#   With deprecated public symbols: ON
#           I/O filters (external):  DEFLATE DECODE ENCODE
#                              MPE:
#                       Direct VFD:
#                          dmalloc:
#   Packages w/ extra debug output:
#                      API Tracing: OFF
#             Using memory checker: OFF
#  Memory allocation sanity checks: OFF
#           Function Stack Tracing: OFF
#        Strict File Format Checks: OFF
#     Optimization Instrumentation:
# C:\Users\ishizuka\Anaconda3\lib\site-packages\h5py\__init__.py:40: UserWarning: h5py is running against HDF5 1.10.5 when it was built against 1.10.4, this may cause problems
#   '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# [2021-02-21 15:01:34] - lgb_KFold_02211501 - train_x shape: (637351, 19)
# [2021-02-21 15:01:34] - lgb_KFold_02211501 - train_y shape: (637351,)
# [2021-02-21 15:01:34] - lgb_KFold_02211501 - start training cv
# [2021-02-21 15:01:34] - lgb_KFold_02211501 - cv method: KFold
# [2021-02-21 15:01:34] - lgb_KFold_02211501 fold 0 - start training
# [2021-02-21 15:14:22] - lgb_KFold_02211501 fold 0 - end training - score 0.07547232825611905
# [2021-02-21 15:14:28] - lgb_KFold_02211501 fold 1 - start training
# [2021-02-21 15:32:06] - lgb_KFold_02211501 fold 1 - end training - score 0.07565459723482433
# [2021-02-21 15:32:13] - lgb_KFold_02211501 fold 2 - start training
# [2021-02-21 15:42:03] - lgb_KFold_02211501 fold 2 - end training - score 0.0756683538359124
# [2021-02-21 15:42:07] - lgb_KFold_02211501 fold 3 - start training
# [2021-02-21 15:59:10] - lgb_KFold_02211501 fold 3 - end training - score 0.0752586944226252
# [2021-02-21 15:59:17] - lgb_KFold_02211501 fold 4 - start training
# [2021-02-21 16:18:21] - lgb_KFold_02211501 fold 4 - end training - score 0.07487560330083853
# [2021-02-21 16:18:27] - lgb_KFold_02211501 - end training cv - score 0.0753859154100639
# name:lgb_KFold_02211501	score:0.0753859154100639	score0:0.07547232825611905	score1:0.07565459723482433	score2:0.0756683538359124	score3:0.0752586944226252	score4:0.07487560330083853
# mean: 0.0753859154100639, std: 0.0002953073638711523
# [2021-02-21 16:18:40] - lgb_KFold_02211501 - start prediction cv
# [2021-02-21 16:18:41] - lgb_KFold_02211501 - start prediction fold:0
# [2021-02-21 16:19:08] - lgb_KFold_02211501 - end prediction fold:0
# [2021-02-21 16:19:08] - lgb_KFold_02211501 - start prediction fold:1
# [2021-02-21 16:19:37] - lgb_KFold_02211501 - end prediction fold:1
# [2021-02-21 16:19:37] - lgb_KFold_02211501 - start prediction fold:2
# [2021-02-21 16:19:47] - lgb_KFold_02211501 - end prediction fold:2
# [2021-02-21 16:19:47] - lgb_KFold_02211501 - start prediction fold:3
# [2021-02-21 16:20:06] - lgb_KFold_02211501 - end prediction fold:3
# [2021-02-21 16:20:06] - lgb_KFold_02211501 - start prediction fold:4
# [2021-02-21 16:20:26] - lgb_KFold_02211501 - end prediction fold:4
# [2021-02-21 16:20:26] - lgb_KFold_02211501 - end prediction cv
# [2021-02-21 16:20:26] - lgb_KFold_02211501 - start create submission
# [2021-02-21 16:20:27] - lgb_KFold_02211501 - end create submission
#         市区町村コード 都道府県名     地区名      最寄駅：名称  ...   改装 取引の事情等  面積_2000   取引年
# 0          1108   北海道    大谷地東         大谷地  ...  未改装    NaN    False  2010
# 3          1108   北海道  厚別中央２条  ひばりが丘(北海道)  ...  未改装    NaN    False  2016
# 4          1108   北海道   厚別東４条       新さっぽろ  ...  未改装    NaN    False  2013
# 5          1101   北海道   南１１条西        中島公園  ...  未改装    NaN    False  2017
# 6          1101   北海道   南１３条西         幌平橋  ...  未改装    NaN    False  2010
# ...         ...   ...     ...         ...  ...  ...    ...      ...   ...
# 637343    47211   沖縄県      住吉         NaN  ...  未改装    NaN    False  2012
# 637345    47208   沖縄県      宮城         NaN  ...  未改装    NaN    False  2020
# 637346    47211   沖縄県      美里         NaN  ...  未改装    NaN    False  2018
# 637349    47201   沖縄県      松尾     県庁前(沖縄)  ...  未改装    NaN    False  2019
# 637350    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2017
#
# [509880 rows x 19 columns]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.219464 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11726
# [LightGBM] [Info] Number of data points in the train set: 509880, number of used features: 18
# [LightGBM] [Info] Start training from score 7.217515
#         市区町村コード 都道府県名    地区名 最寄駅：名称  ...   改装 取引の事情等  面積_2000   取引年
# 0          1108   北海道   大谷地東    大谷地  ...  未改装    NaN    False  2010
# 1          1101   北海道   南９条西   中島公園  ...  未改装    NaN    False  2018
# 2          1101   北海道   北３条西  西１１丁目  ...  未改装    NaN    False  2010
# 4          1108   北海道  厚別東４条  新さっぽろ  ...  未改装    NaN    False  2013
# 5          1101   北海道  南１１条西   中島公園  ...  未改装    NaN    False  2017
# ...         ...   ...    ...    ...  ...  ...    ...      ...   ...
# 637345    47208   沖縄県     宮城    NaN  ...  未改装    NaN    False  2020
# 637346    47211   沖縄県     美里    NaN  ...  未改装    NaN    False  2018
# 637347    47211   沖縄県     泡瀬    NaN  ...  未改装    NaN    False  2015
# 637348    47208   沖縄県     城間    NaN  ...  未改装    NaN    False  2010
# 637350    47208   沖縄県     城間    NaN  ...  未改装    NaN    False  2017
#
# [509881 rows x 19 columns]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.320260 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11681
# [LightGBM] [Info] Number of data points in the train set: 509881, number of used features: 18
# [LightGBM] [Info] Start training from score 7.218029
#         市区町村コード 都道府県名     地区名      最寄駅：名称  ...   改装 取引の事情等  面積_2000   取引年
# 1          1101   北海道    南９条西        中島公園  ...  未改装    NaN    False  2018
# 2          1101   北海道    北３条西       西１１丁目  ...  未改装    NaN    False  2010
# 3          1108   北海道  厚別中央２条  ひばりが丘(北海道)  ...  未改装    NaN    False  2016
# 4          1108   北海道   厚別東４条       新さっぽろ  ...  未改装    NaN    False  2013
# 5          1101   北海道   南１１条西        中島公園  ...  未改装    NaN    False  2017
# ...         ...   ...     ...         ...  ...  ...    ...      ...   ...
# 637344    47201   沖縄県      識名         NaN  ...  未改装    NaN    False  2008
# 637345    47208   沖縄県      宮城         NaN  ...  未改装    NaN    False  2020
# 637347    47211   沖縄県      泡瀬         NaN  ...  未改装    NaN    False  2015
# 637348    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2010
# 637349    47201   沖縄県      松尾     県庁前(沖縄)  ...  未改装    NaN    False  2019
#
# [509881 rows x 19 columns]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.061335 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11660
# [LightGBM] [Info] Number of data points in the train set: 509881, number of used features: 18
# [LightGBM] [Info] Start training from score 7.217107
#         市区町村コード 都道府県名     地区名      最寄駅：名称  ...   改装 取引の事情等  面積_2000   取引年
# 0          1108   北海道    大谷地東         大谷地  ...  未改装    NaN    False  2010
# 1          1101   北海道    南９条西        中島公園  ...  未改装    NaN    False  2018
# 2          1101   北海道    北３条西       西１１丁目  ...  未改装    NaN    False  2010
# 3          1108   北海道  厚別中央２条  ひばりが丘(北海道)  ...  未改装    NaN    False  2016
# 6          1101   北海道   南１３条西         幌平橋  ...  未改装    NaN    False  2010
# ...         ...   ...     ...         ...  ...  ...    ...      ...   ...
# 637346    47211   沖縄県      美里         NaN  ...  未改装    NaN    False  2018
# 637347    47211   沖縄県      泡瀬         NaN  ...  未改装    NaN    False  2015
# 637348    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2010
# 637349    47201   沖縄県      松尾     県庁前(沖縄)  ...  未改装    NaN    False  2019
# 637350    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2017
#
# [509881 rows x 19 columns]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.177177 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11658
# [LightGBM] [Info] Number of data points in the train set: 509881, number of used features: 18
# [LightGBM] [Info] Start training from score 7.216959
#         市区町村コード 都道府県名     地区名      最寄駅：名称  ...   改装 取引の事情等  面積_2000   取引年
# 0          1108   北海道    大谷地東         大谷地  ...  未改装    NaN    False  2010
# 1          1101   北海道    南９条西        中島公園  ...  未改装    NaN    False  2018
# 2          1101   北海道    北３条西       西１１丁目  ...  未改装    NaN    False  2010
# 3          1108   北海道  厚別中央２条  ひばりが丘(北海道)  ...  未改装    NaN    False  2016
# 4          1108   北海道   厚別東４条       新さっぽろ  ...  未改装    NaN    False  2013
# ...         ...   ...     ...         ...  ...  ...    ...      ...   ...
# 637346    47211   沖縄県      美里         NaN  ...  未改装    NaN    False  2018
# 637347    47211   沖縄県      泡瀬         NaN  ...  未改装    NaN    False  2015
# 637348    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2010
# 637349    47201   沖縄県      松尾     県庁前(沖縄)  ...  未改装    NaN    False  2019
# 637350    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2017
#
# [509881 rows x 19 columns]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.119838 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11650
# [LightGBM] [Info] Number of data points in the train set: 509881, number of used features: 18
# [LightGBM] [Info] Start training from score 7.217509
# 2021-02-21 15:00:11.655957: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_101.dll'; dlerror: cudart64_101.dll not found
# 2021-02-21 15:00:11.656739: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Warning! ***HDF5 library version mismatched error***
# The HDF5 header files used to compile this application do not match
# the version used by the HDF5 library to which this application is linked.
# Data corruption or segmentation faults may occur if the application continues.
# This can happen when an application was compiled by one version of HDF5 but
# linked with a different version of static or shared HDF5 library.
# You should recompile the application or check your shared library related
# settings such as 'LD_LIBRARY_PATH'.
# 'HDF5_DISABLE_VERSION_CHECK' environment variable is set to 1, application will
# continue at your own risk.
# Headers are 1.10.4, library is 1.10.5
#         SUMMARY OF THE HDF5 CONFIGURATION
#         =================================
#
# General Information:
# -------------------
#                    HDF5 Version: 1.10.5
#                   Configured on: 2019-03-04
#                   Configured by: Visual Studio 15 2017 Win64
#                     Host system: Windows-10.0.17763
#               Uname information: Windows
#                        Byte sex: little-endian
#              Installation point: C:/Program Files/HDF5
#
# Compiling Options:
# ------------------
#                      Build Mode:
#               Debugging Symbols:
#                         Asserts:
#                       Profiling:
#              Optimization Level:
#
# Linking Options:
# ----------------
#                       Libraries:
#   Statically Linked Executables: OFF
#                         LDFLAGS: /machine:x64
#                      H5_LDFLAGS:
#                      AM_LDFLAGS:
#                 Extra libraries:
#                        Archiver:
#                          Ranlib:
#
# Languages:
# ----------
#                               C: yes
#                      C Compiler: C:/Program Files (x86)/Microsoft Visual Studio/2017/Community/VC/Tools/MSVC/14.16.27023/bin/Hostx86/x64/cl.exe 19.16.27027.1
#                        CPPFLAGS:
#                     H5_CPPFLAGS:
#                     AM_CPPFLAGS:
#                          CFLAGS:  /DWIN32 /D_WINDOWS /W3
#                       H5_CFLAGS:
#                       AM_CFLAGS:
#                Shared C Library: YES
#                Static C Library: YES
#
#                         Fortran: OFF
#                Fortran Compiler:
#                   Fortran Flags:
#                H5 Fortran Flags:
#                AM Fortran Flags:
#          Shared Fortran Library: YES
#          Static Fortran Library: YES
#
#                             C++: ON
#                    C++ Compiler: C:/Program Files (x86)/Microsoft Visual Studio/2017/Community/VC/Tools/MSVC/14.16.27023/bin/Hostx86/x64/cl.exe 19.16.27027.1
#                       C++ Flags: /DWIN32 /D_WINDOWS /W3 /GR /EHsc
#                    H5 C++ Flags:
#                    AM C++ Flags:
#              Shared C++ Library: YES
#              Static C++ Library: YES
#
#                             JAVA: OFF
#                    JAVA Compiler:
#
# Features:
# ---------
#                    Parallel HDF5: OFF
# Parallel Filtered Dataset Writes:
#               Large Parallel I/O:
#               High-level library: ON
#                     Threadsafety: OFF
#              Default API mapping: v110
#   With deprecated public symbols: ON
#           I/O filters (external):  DEFLATE DECODE ENCODE
#                              MPE:
#                       Direct VFD:
#                          dmalloc:
#   Packages w/ extra debug output:
#                      API Tracing: OFF
#             Using memory checker: OFF
#  Memory allocation sanity checks: OFF
#           Function Stack Tracing: OFF
#        Strict File Format Checks: OFF
#     Optimization Instrumentation:
# C:\Users\ishizuka\Anaconda3\lib\site-packages\h5py\__init__.py:40: UserWarning: h5py is running against HDF5 1.10.5 when it was built against 1.10.4, this may cause problems
#   '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# [2021-02-21 15:00:24] - lgb_KFold_02211500 - train_x shape: (637351, 19)
# [2021-02-21 15:00:24] - lgb_KFold_02211500 - train_y shape: (637351,)
# [2021-02-21 15:00:24] - lgb_KFold_02211500 - start training cv
# [2021-02-21 15:00:24] - lgb_KFold_02211500 - cv method: KFold
# [2021-02-21 15:00:24] - lgb_KFold_02211500 fold 0 - start training
# [2021-02-21 15:12:14] - lgb_KFold_02211500 fold 0 - end training - score 0.0754723282561198
# [2021-02-21 15:12:20] - lgb_KFold_02211500 fold 1 - start training
# [2021-02-21 15:35:05] - lgb_KFold_02211500 fold 1 - end training - score 0.07565459723482433
# [2021-02-21 15:35:16] - lgb_KFold_02211500 fold 2 - start training
# [2021-02-21 15:43:53] - lgb_KFold_02211500 fold 2 - end training - score 0.0756683538359124
# [2021-02-21 15:43:57] - lgb_KFold_02211500 fold 3 - start training
# [2021-02-21 16:08:26] - lgb_KFold_02211500 fold 3 - end training - score 0.0752586944226252
# [2021-02-21 16:08:31] - lgb_KFold_02211500 fold 4 - start training
# [2021-02-21 16:23:15] - lgb_KFold_02211500 fold 4 - end training - score 0.07487560330083853
# [2021-02-21 16:23:21] - lgb_KFold_02211500 - end training cv - score 0.07538591541006405
# name:lgb_KFold_02211500	score:0.07538591541006405	score0:0.0754723282561198	score1:0.07565459723482433	score2:0.0756683538359124	score3:0.0752586944226252	score4:0.07487560330083853
# mean: 0.07538591541006405, std: 0.00029530736387119616
# [2021-02-21 16:23:32] - lgb_KFold_02211500 - start prediction cv
# [2021-02-21 16:23:32] - lgb_KFold_02211500 - start prediction fold:0
# [2021-02-21 16:23:54] - lgb_KFold_02211500 - end prediction fold:0
# [2021-02-21 16:23:54] - lgb_KFold_02211500 - start prediction fold:1
# [2021-02-21 16:24:14] - lgb_KFold_02211500 - end prediction fold:1
# [2021-02-21 16:24:14] - lgb_KFold_02211500 - start prediction fold:2
# [2021-02-21 16:24:25] - lgb_KFold_02211500 - end prediction fold:2
# [2021-02-21 16:24:25] - lgb_KFold_02211500 - start prediction fold:3
# [2021-02-21 16:24:49] - lgb_KFold_02211500 - end prediction fold:3
# [2021-02-21 16:24:49] - lgb_KFold_02211500 - start prediction fold:4
# [2021-02-21 16:25:14] - lgb_KFold_02211500 - end prediction fold:4
# [2021-02-21 16:25:14] - lgb_KFold_02211500 - end prediction cv
# [2021-02-21 16:25:15] - lgb_KFold_02211500 - start create submission
# [2021-02-21 16:25:15] - lgb_KFold_02211500 - end create submission
#         市区町村コード 都道府県名     地区名      最寄駅：名称  ...   改装 取引の事情等  面積_2000   取引年
# 0          1108   北海道    大谷地東         大谷地  ...  未改装    NaN    False  2010
# 3          1108   北海道  厚別中央２条  ひばりが丘(北海道)  ...  未改装    NaN    False  2016
# 4          1108   北海道   厚別東４条       新さっぽろ  ...  未改装    NaN    False  2013
# 5          1101   北海道   南１１条西        中島公園  ...  未改装    NaN    False  2017
# 6          1101   北海道   南１３条西         幌平橋  ...  未改装    NaN    False  2010
# ...         ...   ...     ...         ...  ...  ...    ...      ...   ...
# 637343    47211   沖縄県      住吉         NaN  ...  未改装    NaN    False  2012
# 637345    47208   沖縄県      宮城         NaN  ...  未改装    NaN    False  2020
# 637346    47211   沖縄県      美里         NaN  ...  未改装    NaN    False  2018
# 637349    47201   沖縄県      松尾     県庁前(沖縄)  ...  未改装    NaN    False  2019
# 637350    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2017
#
# [509880 rows x 19 columns]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.037581 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11726
# [LightGBM] [Info] Number of data points in the train set: 509880, number of used features: 18
# [LightGBM] [Info] Start training from score 7.217515
#         市区町村コード 都道府県名    地区名 最寄駅：名称  ...   改装 取引の事情等  面積_2000   取引年
# 0          1108   北海道   大谷地東    大谷地  ...  未改装    NaN    False  2010
# 1          1101   北海道   南９条西   中島公園  ...  未改装    NaN    False  2018
# 2          1101   北海道   北３条西  西１１丁目  ...  未改装    NaN    False  2010
# 4          1108   北海道  厚別東４条  新さっぽろ  ...  未改装    NaN    False  2013
# 5          1101   北海道  南１１条西   中島公園  ...  未改装    NaN    False  2017
# ...         ...   ...    ...    ...  ...  ...    ...      ...   ...
# 637345    47208   沖縄県     宮城    NaN  ...  未改装    NaN    False  2020
# 637346    47211   沖縄県     美里    NaN  ...  未改装    NaN    False  2018
# 637347    47211   沖縄県     泡瀬    NaN  ...  未改装    NaN    False  2015
# 637348    47208   沖縄県     城間    NaN  ...  未改装    NaN    False  2010
# 637350    47208   沖縄県     城間    NaN  ...  未改装    NaN    False  2017
#
# [509881 rows x 19 columns]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.055806 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11681
# [LightGBM] [Info] Number of data points in the train set: 509881, number of used features: 18
# [LightGBM] [Info] Start training from score 7.218029
#         市区町村コード 都道府県名     地区名      最寄駅：名称  ...   改装 取引の事情等  面積_2000   取引年
# 1          1101   北海道    南９条西        中島公園  ...  未改装    NaN    False  2018
# 2          1101   北海道    北３条西       西１１丁目  ...  未改装    NaN    False  2010
# 3          1108   北海道  厚別中央２条  ひばりが丘(北海道)  ...  未改装    NaN    False  2016
# 4          1108   北海道   厚別東４条       新さっぽろ  ...  未改装    NaN    False  2013
# 5          1101   北海道   南１１条西        中島公園  ...  未改装    NaN    False  2017
# ...         ...   ...     ...         ...  ...  ...    ...      ...   ...
# 637344    47201   沖縄県      識名         NaN  ...  未改装    NaN    False  2008
# 637345    47208   沖縄県      宮城         NaN  ...  未改装    NaN    False  2020
# 637347    47211   沖縄県      泡瀬         NaN  ...  未改装    NaN    False  2015
# 637348    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2010
# 637349    47201   沖縄県      松尾     県庁前(沖縄)  ...  未改装    NaN    False  2019
#
# [509881 rows x 19 columns]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.575764 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11660
# [LightGBM] [Info] Number of data points in the train set: 509881, number of used features: 18
# [LightGBM] [Info] Start training from score 7.217107
#         市区町村コード 都道府県名     地区名      最寄駅：名称  ...   改装 取引の事情等  面積_2000   取引年
# 0          1108   北海道    大谷地東         大谷地  ...  未改装    NaN    False  2010
# 1          1101   北海道    南９条西        中島公園  ...  未改装    NaN    False  2018
# 2          1101   北海道    北３条西       西１１丁目  ...  未改装    NaN    False  2010
# 3          1108   北海道  厚別中央２条  ひばりが丘(北海道)  ...  未改装    NaN    False  2016
# 6          1101   北海道   南１３条西         幌平橋  ...  未改装    NaN    False  2010
# ...         ...   ...     ...         ...  ...  ...    ...      ...   ...
# 637346    47211   沖縄県      美里         NaN  ...  未改装    NaN    False  2018
# 637347    47211   沖縄県      泡瀬         NaN  ...  未改装    NaN    False  2015
# 637348    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2010
# 637349    47201   沖縄県      松尾     県庁前(沖縄)  ...  未改装    NaN    False  2019
# 637350    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2017
#
# [509881 rows x 19 columns]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.065596 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11658
# [LightGBM] [Info] Number of data points in the train set: 509881, number of used features: 18
# [LightGBM] [Info] Start training from score 7.216959
#         市区町村コード 都道府県名     地区名      最寄駅：名称  ...   改装 取引の事情等  面積_2000   取引年
# 0          1108   北海道    大谷地東         大谷地  ...  未改装    NaN    False  2010
# 1          1101   北海道    南９条西        中島公園  ...  未改装    NaN    False  2018
# 2          1101   北海道    北３条西       西１１丁目  ...  未改装    NaN    False  2010
# 3          1108   北海道  厚別中央２条  ひばりが丘(北海道)  ...  未改装    NaN    False  2016
# 4          1108   北海道   厚別東４条       新さっぽろ  ...  未改装    NaN    False  2013
# ...         ...   ...     ...         ...  ...  ...    ...      ...   ...
# 637346    47211   沖縄県      美里         NaN  ...  未改装    NaN    False  2018
# 637347    47211   沖縄県      泡瀬         NaN  ...  未改装    NaN    False  2015
# 637348    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2010
# 637349    47201   沖縄県      松尾     県庁前(沖縄)  ...  未改装    NaN    False  2019
# 637350    47208   沖縄県      城間         NaN  ...  未改装    NaN    False  2017
#
# [509881 rows x 19 columns]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.249456 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11650
# [LightGBM] [Info] Number of data points in the train set: 509881, number of used features: 18
# [LightGBM] [Info] Start training from score 7.217509
